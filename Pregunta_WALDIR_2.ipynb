# %% [markdown]
# (a) Usando SCOPUS (https://www.scopus.com/) obtenga un archivo CSV con al
# menos 10 artículos científicos para estas palabras clave. Asegúrese de
# disponer de la columna “Abstract”.

# %%
import pandas as pd

# %%
df = pd.read_csv('scopus_waldir.csv')

# %%
df.head(2)
# Out:
#                                      Authors  \
# 0  Bagustari B.A.; Yazid S.; Alshehadeh A.R.
# 1                           Gong R.; Chen Q.
#
#                                    Author full names  \
# 0  Bagustari, Bintang Annisa (57210235140); Yazid...
# 1    Gong, Rui (57578232900); Chen, Qi (57577337800)
#
#                            Author(s) ID  \
# 0  57210235140; 6506236236; 57200408859
# 1              57578232900; 57577337800
#
#                                                Title  Year  \
# 0  Analyzing Fog Computing Technologies for Enhan...  2023
# 1  Research on application of cloud computing tec...  2021
#
#                                         Source title Volume Issue Art. No.  \
# 0  International Journal of Advances in Soft Comp...     15     1      NaN
# 1  Proceedings - 2021 2nd International Conferenc...    NaN   NaN      NaN
#
#    Page start  Page end  Page count  Cited by  \
# 0       133.0     143.0        10.0         0
# 1       471.0     474.0         3.0         0
#
#                                 DOI  \
# 0         10.15849/IJASCA.230320.09
# 1  10.1109/ICISE-IE53922.2021.00114
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                             Abstract     Document Type  \
# 0  The use of a wireless communication network ha...           Article
# 1  Nowadays, with the rapid development of inform...  Conference paper
#
#   Publication Stage Open Access  Source
# 0             Final         NaN  Scopus
# 1             Final         NaN  Scopus

# %%
df["Abstract"]
# Out:
# 0     The use of a wireless communication network ha...
# 1     Nowadays, with the rapid development of inform...
# 2     In higher learning, cloud computing has become...
# 3     There are many innovations applied in the educ...
# 4     The intersection of education and technology h...
# 5     FOG COMPUTING FOR INTELLIGENT CLOUD IOT SYSTEM...
# 6     Universities require basic changes in knowledg...
# 7     Social media outlets such as Twitter and Faceb...
# 8     E-learning is a learning system in which educa...
# 9     The evaluation of teaching quality in colleges...
# 10    With the rapid development of Internet technol...
# 11    In the same way as cloud computing, Software a...
# 12    Mobile internet, cloud computing, big data tec...
# 13    See how the principles of Service Science gove...
# 14    Physical learning, communication, and collabor...
# 15    Educational administration management is the p...
# 16    Constructing intelligent campus is the inevita...
# 17    Cloud Computing (CC) and virtualization concep...
# 18    Web 2.0 technologies including cloud computing...
# 19    The progressive development of higher educatio...
# 20    Purpose: Ten-year Plan for the Development of ...
# 21    There are 24.5 million visually impaired and b...
# 22    The proceedings contain 43 papers. The topics ...
# 23    Technologies based on cloud computing is one o...
# 24    In this ever-progressive digital era, conventi...
# 25    Technological advances over the last decade ha...
# 26    Cloud Computing technology has revolutionized ...
# 27    Educational institutions are transferring anal...
# 28    Universities require basic changes in knowledg...
# 29    Virtualization is a key cost-cutting technolog...
# 30    This paper focuses on COSMOS - <u>C</u>loud en...
# 31    The proposed interactive online group within t...
# 32    In an era witnessing the rapid development of ...
# 33    Combined with educational information technolo...
# 34    We experience weather every day, yet many peop...
# 35    Despite its hype, cloud computing, with its dy...
# 36    Online code sharing and documentation platform...
# 37    Mobile computing is becoming ubiquitous across...
# 38    As a consequence of the COVID-19 pandemic, the...
# 39    The paper is devoted to the problem of studyin...
# 40    Nowadays, educational and research institution...
# 41    Twenty-first century technology has changed th...
# 42    In the context of the era of big data, the edu...
# 43    The intersection between technology and educat...
# 44    Human-computer interaction talks about designi...
# 45    In this paper we present "ML-AR" Practice Modu...
# 46    In this paper, we propose a cognitive system t...
# 47    The primary goal of the study is to optimize a...
# 48    In our fast-paced society, due to the intercon...
# 49    Because of the increasing heterogeneity among ...
# 50    Based on the cloud computing artificial intell...
# 51    With the development of technology, the bandwi...
# 52    The change in ICT supported business is charac...
# 53    This article seeks to share an immersive educa...
# 54    The article is devoted to the systematization ...
# 55    In order to realize unified deployment and sys...
# 56    In the era of digitization, higher education i...
# Name: Abstract, dtype: object

# %%
df.shape
# Out:
# (57, 20)

# %% [markdown]
# (b) Usando matplotlib y/o seaborn grafique un diagrama de barras con los
# tipos de publicación versus la cantidad.

# %%
# prompt: haz una grafica de barras con matplotlib mostrando los tipos de documentos y la cantidad

import matplotlib.pyplot as plt

# Contar la cantidad de cada tipo de documento
doc_counts = df['Document Type'].value_counts()

# Crear la gráfica de barras
plt.figure(figsize=(10, 6))  # Ajustar el tamaño de la figura
plt.bar(doc_counts.index, doc_counts.values)
plt.xlabel('Tipo de Documento')
plt.ylabel('Cantidad')
plt.title('Cantidad de Documentos por Tipo')
plt.xticks(rotation=45, ha='right')  # Rotar las etiquetas del eje x para una mejor visualización
plt.tight_layout()  # Ajustar el diseño para evitar que las etiquetas se superpongan
plt.show()

# %% [markdown]
# (c) Usando Missingno evalúe si existen datos faltantes.

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <Axes: >
